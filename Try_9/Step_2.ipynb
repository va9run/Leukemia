# %%
# Step-2:
#### 1. Image Contrast
#### 2. Data Split (Train(80), Validation(20))
#### 3. Transfer learning

# %%
pip install tensorflow-addons --user
# Out:
# Collecting tensorflow-addons
#   Using cached tensorflow_addons-0.20.0-cp39-cp39-win_amd64.whl (746 kB)
# Requirement already satisfied: packaging in c:\users\v4run\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow-addons) (21.3)
# Collecting typeguard<3.0.0,>=2.7
#   Using cached typeguard-2.13.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\v4run\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from packaging->tensorflow-addons) (3.0.9)
# Installing collected packages: typeguard, tensorflow-addons
# Successfully installed tensorflow-addons-0.20.0 typeguard-2.13.3
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the 'C:\Users\v4run\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
import numpy as np
import tensorflow as tf
import keras
from imageContrast import img_cont
from skimage import exposure
from pylab import *
from keras.models import Sequential
from keras import regularizers
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, concatenate, Input
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
from tensorflow.keras.models import Model
from tensorflow.keras.metrics import AUC
from imageCropping import crop_img
import tensorflow_addons as tfa
# Out:
# C:\Users\v4run\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
trainingDataPath = 'C:/Users/v4run/OneDrive/Desktop/Datasets/C-NMC_Leukemia/TrainingDataset'

# %%
def imgContrastPreprocess(images, labels):
    equalized_images = tf.map_fn(lambda img: tf.py_function(img_cont, [img], Tout=tf.float32), images, fn_output_signature=tf.float32)
    return equalized_images, labels

# %%
train_data = tf.keras.utils.image_dataset_from_directory(
    trainingDataPath,
    seed=21,
    image_size=(256, 256),
    batch_size=32,
    validation_split=0.2,
    subset='training'
)
# Out:
# Found 9625 files belonging to 2 classes.
# Using 7700 files for training.

# %%
val_data = tf.keras.utils.image_dataset_from_directory(
    trainingDataPath,
    seed=21,
    image_size=(256, 256),
    batch_size=32,
    validation_split=0.2,
    subset='validation'
)
# Out:
# Found 9625 files belonging to 2 classes.
# Using 1925 files for validation.

# %%
trainDataset = train_data.map(imgContrastPreprocess).repeat()

# %%
validDataset = val_data.map(imgContrastPreprocess)

# %%
# Model Structure
# parallel branches and dilated convolution using the Keras Functional API

# %%
input_img = Input(shape=(256,256,3))

conv1 = Conv2D(32,(3,3), activation = 'relu', padding='same')(input_img)
conv1 = MaxPooling2D((2,2), padding='same')(conv1)

conv2 = Conv2D(64,(3,3), activation = 'relu', padding='same')(conv1)
conv2 = MaxPooling2D((2,2), padding='same')(conv2)

conv3 = Conv2D(128,(3,3), activation = 'relu', padding='same')(conv2)
conv3 = MaxPooling2D((2,2), padding='same')(conv3)

# Parallel branches
pbranch1 = Conv2D(256,(3,3), activation = 'relu', padding='same')(conv3)
pbranch2 = Conv2D(256,(5,5), activation = 'relu', padding='same')(conv3)
pbranch3 = Conv2D(256,(7,7), activation = 'relu', padding='same')(conv3)

# Concatenate
concatenateBranch = concatenate([pbranch1,pbranch2,pbranch3], axis=-1) #fix this to 3 or -1

# Dilated convulation
dilatedConv = Conv2D(256,(3,3), activation = 'relu', padding='same', dilation_rate=2)(concatenateBranch)
dilatedConv = MaxPooling2D((2,2),padding = 'same')(dilatedConv)

# Flatten and fully connected layers
flat = Flatten()(dilatedConv)
dense1 = Dense(256,activation='relu')(flat)
dense2 = Dense(1,activation='sigmoid')(dense1)

model = Model(inputs=input_img, outputs=dense2)
f1Score = tfa.metrics.F1Score(num_classes=1,average='macro',threshold=0.5)
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[f1Score])
earlyStopping = EarlyStopping(monitor='val_f1_score', patience=10, verbose=1, mode='max')
checkPoint = ModelCheckpoint(
    'C:/Users/v4run/OneDrive/Desktop/Datasets/C-NMC_Leukemia/models/parallelBranch.h5',
    monitor = 'val_f1_score',
    verbose = 1,
    save_best_only=True,
    mode='max'
)
history = model.fit(
    trainDataset,
    steps_per_epoch=floor(7700//32),
    epochs=100,
    validation_data=validDataset,
    validation_steps=floor(1925//32),
    callbacks=[earlyStopping,checkPoint]
)

loss, accuracy = model.evaluate(validDataset,steps=floor(1925//32))
# Out:
# Epoch 1/100
# 240/240 [==============================] - ETA: 0s - loss: 0.6972 - f1_score: 0.6070
# Epoch 1: val_f1_score improved from -inf to 0.76456, saving model to C:/Users/v4run/OneDrive/Desktop/Datasets/C-NMC_Leukemia/models\parallelBranch.h5
# 240/240 [==============================] - 1471s 6s/step - loss: 0.6972 - f1_score: 0.6070 - val_loss: 0.5471 - val_f1_score: 0.7646
# Epoch 2/100
# 240/240 [==============================] - ETA: 0s - loss: 0.4527 - f1_score: 0.7968
# Epoch 2: val_f1_score improved from 0.76456 to 0.82945, saving model to C:/Users/v4run/OneDrive/Desktop/Datasets/C-NMC_Leukemia/models\parallelBranch.h5
# 240/240 [==============================] - 1470s 6s/step - loss: 0.4527 - f1_score: 0.7968 - val_loss: 0.3813 - val_f1_score: 0.8294
# Epoch 3/100
# 240/240 [==============================] - ETA: 0s - loss: 0.3257 - f1_score: 0.8652
# Epoch 3: val_f1_score improved from 0.82945 to 0.85298, saving model to C:/Users/v4run/OneDrive/Desktop/Datasets/C-NMC_Leukemia/models\parallelBranch.h5
# 240/240 [==============================] - 1473s 6s/step - loss: 0.3257 - f1_score: 0.8652 - val_loss: 0.3789 - val_f1_score: 0.8530
# Epoch 4/100
# 240/240 [==============================] - ETA: 0s - loss: 0.2794 - f1_score: 0.8895
# Epoch 4: val_f1_score improved from 0.85298 to 0.85481, saving model to C:/Users/v4run/OneDrive/Desktop/Datasets/C-NMC_Leukemia/models\parallelBranch.h5
# 240/240 [==============================] - 1471s 6s/step - loss: 0.2794 - f1_score: 0.8895 - val_loss: 0.3258 - val_f1_score: 0.8548
# Epoch 5/100
# 240/240 [==============================] - ETA: 0s - loss: 0.2506 - f1_score: 0.9018
# Epoch 5: val_f1_score improved from 0.85481 to 0.89105, saving model to C:/Users/v4run/OneDrive/Desktop/Datasets/C-NMC_Leukemia/models\parallelBranch.h5
# 240/240 [==============================] - 1475s 6s/step - loss: 0.2506 - f1_score: 0.9018 - val_loss: 0.2824 - val_f1_score: 0.8910
# Epoch 6/100
# 240/240 [==============================] - ETA: 0s - loss: 0.2252 - f1_score: 0.9118
# Epoch 6: val_f1_score did not improve from 0.89105
# 240/240 [==============================] - 1389s 6s/step - loss: 0.2252 - f1_score: 0.9118 - val_loss: 0.3772 - val_f1_score: 0.8219
# Epoch 7/100
# 240/240 [==============================] - ETA: 0s - loss: 0.1948 - f1_score: 0.9251
# Epoch 7: val_f1_score improved from 0.89105 to 0.89437, saving model to C:/Users/v4run/OneDrive/Desktop/Datasets/C-NMC_Leukemia/models\parallelBranch.h5
# 240/240 [==============================] - 1342s 6s/step - loss: 0.1948 - f1_score: 0.9251 - val_loss: 0.2791 - val_f1_score: 0.8944
# Epoch 8/100
# 240/240 [==============================] - ETA: 0s - loss: 0.1803 - f1_score: 0.9300
# Epoch 8: val_f1_score did not improve from 0.89437
# 240/240 [==============================] - 1336s 6s/step - loss: 0.1803 - f1_score: 0.9300 - val_loss: 0.3266 - val_f1_score: 0.8924
# Epoch 9/100
# 240/240 [==============================] - ETA: 0s - loss: 0.1460 - f1_score: 0.9437
# Epoch 9: val_f1_score did not improve from 0.89437
# 240/240 [==============================] - 1325s 6s/step - loss: 0.1460 - f1_score: 0.9437 - val_loss: 0.3593 - val_f1_score: 0.8915
# Epoch 10/100
# 240/240 [==============================] - ETA: 0s - loss: 0.1126 - f1_score: 0.9584
# Epoch 10: val_f1_score did not improve from 0.89437
# 240/240 [==============================] - 1326s 6s/step - loss: 0.1126 - f1_score: 0.9584 - val_loss: 0.3568 - val_f1_score: 0.8925
# Epoch 11/100
# 240/240 [==============================] - ETA: 0s - loss: 0.0900 - f1_score: 0.9643
# Epoch 11: val_f1_score did not improve from 0.89437
# 240/240 [==============================] - 1322s 6s/step - loss: 0.0900 - f1_score: 0.9643 - val_loss: 0.4248 - val_f1_score: 0.8871
# Epoch 12/100
# 240/240 [==============================] - ETA: 0s - loss: 0.0604 - f1_score: 0.9768
# Epoch 12: val_f1_score improved from 0.89437 to 0.89809, saving model to C:/Users/v4run/OneDrive/Desktop/Datasets/C-NMC_Leukemia/models\parallelBranch.h5
# 240/240 [==============================] - 1318s 5s/step - loss: 0.0604 - f1_score: 0.9768 - val_loss: 0.4938 - val_f1_score: 0.8981
# Epoch 13/100
# 240/240 [==============================] - ETA: 0s - loss: 0.0816 - f1_score: 0.9693
# Epoch 13: val_f1_score did not improve from 0.89809
# 240/240 [==============================] - 1314s 5s/step - loss: 0.0816 - f1_score: 0.9693 - val_loss: 0.4736 - val_f1_score: 0.8945
# Epoch 14/100
# 240/240 [==============================] - ETA: 0s - loss: 0.0592 - f1_score: 0.9773
# Epoch 14: val_f1_score did not improve from 0.89809
# 240/240 [==============================] - 1304s 5s/step - loss: 0.0592 - f1_score: 0.9773 - val_loss: 0.4449 - val_f1_score: 0.8970
# Epoch 15/100
# 240/240 [==============================] - ETA: 0s - loss: 0.0457 - f1_score: 0.9836
# Epoch 15: val_f1_score did not improve from 0.89809
# 240/240 [==============================] - 1310s 5s/step - loss: 0.0457 - f1_score: 0.9836 - val_loss: 0.6011 - val_f1_score: 0.8883
# Epoch 16/100
# 240/240 [==============================] - ETA: 0s - loss: 0.0331 - f1_score: 0.9883
# Epoch 16: val_f1_score improved from 0.89809 to 0.90772, saving model to C:/Users/v4run/OneDrive/Desktop/Datasets/C-NMC_Leukemia/models\parallelBranch.h5
# 240/240 [==============================] - 1296s 5s/step - loss: 0.0331 - f1_score: 0.9883 - val_loss: 0.4828 - val_f1_score: 0.9077
# Epoch 17/100
# 240/240 [==============================] - ETA: 0s - loss: 0.0232 - f1_score: 0.9927
# Epoch 17: val_f1_score did not improve from 0.90772
# 240/240 [==============================] - 1292s 5s/step - loss: 0.0232 - f1_score: 0.9927 - val_loss: 0.8003 - val_f1_score: 0.8905
# Epoch 18/100
# 240/240 [==============================] - ETA: 0s - loss: 0.0449 - f1_score: 0.9839
# Epoch 18: val_f1_score did not improve from 0.90772
# 240/240 [==============================] - 1285s 5s/step - loss: 0.0449 - f1_score: 0.9839 - val_loss: 0.6281 - val_f1_score: 0.8960
# Epoch 19/100
# 240/240 [==============================] - ETA: 0s - loss: 0.0351 - f1_score: 0.9891
# Epoch 19: val_f1_score did not improve from 0.90772
# 240/240 [==============================] - 1281s 5s/step - loss: 0.0351 - f1_score: 0.9891 - val_loss: 0.5772 - val_f1_score: 0.8688
# Epoch 20/100
# 240/240 [==============================] - ETA: 0s - loss: 0.0279 - f1_score: 0.9903
# Epoch 20: val_f1_score did not improve from 0.90772
# 240/240 [==============================] - 1277s 5s/step - loss: 0.0279 - f1_score: 0.9903 - val_loss: 0.5747 - val_f1_score: 0.9060
# Epoch 21/100
# 240/240 [==============================] - ETA: 0s - loss: 0.0171 - f1_score: 0.9945
# Epoch 21: val_f1_score did not improve from 0.90772
# 240/240 [==============================] - 1279s 5s/step - loss: 0.0171 - f1_score: 0.9945 - val_loss: 0.7190 - val_f1_score: 0.8864
# Epoch 22/100
# 240/240 [==============================] - ETA: 0s - loss: 0.0263 - f1_score: 0.9906
# Epoch 22: val_f1_score did not improve from 0.90772
# 240/240 [==============================] - 1279s 5s/step - loss: 0.0263 - f1_score: 0.9906 - val_loss: 0.7079 - val_f1_score: 0.8664
# Epoch 23/100
# 240/240 [==============================] - ETA: 0s - loss: 0.0227 - f1_score: 0.9904
# Epoch 23: val_f1_score did not improve from 0.90772
# 240/240 [==============================] - 1280s 5s/step - loss: 0.0227 - f1_score: 0.9904 - val_loss: 0.7187 - val_f1_score: 0.8928
# Epoch 24/100
# 240/240 [==============================] - ETA: 0s - loss: 0.0421 - f1_score: 0.9862
# Epoch 24: val_f1_score did not improve from 0.90772
# 240/240 [==============================] - 1281s 5s/step - loss: 0.0421 - f1_score: 0.9862 - val_loss: 0.5644 - val_f1_score: 0.8820
# Epoch 25/100
# 240/240 [==============================] - ETA: 0s - loss: 0.0074 - f1_score: 0.9974
# Epoch 25: val_f1_score did not improve from 0.90772
# 240/240 [==============================] - 1278s 5s/step - loss: 0.0074 - f1_score: 0.9974 - val_loss: 0.6457 - val_f1_score: 0.8866
# Epoch 26/100
# 240/240 [==============================] - ETA: 0s - loss: 0.0022 - f1_score: 0.9996
# Epoch 26: val_f1_score improved from 0.90772 to 0.91221, saving model to C:/Users/v4run/OneDrive/Desktop/Datasets/C-NMC_Leukemia/models\parallelBranch.h5
# 240/240 [==============================] - 1273s 5s/step - loss: 0.0022 - f1_score: 0.9996 - val_loss: 0.7225 - val_f1_score: 0.9122
# Epoch 27/100
# 240/240 [==============================] - ETA: 0s - loss: 0.0332 - f1_score: 0.9893
# Epoch 27: val_f1_score did not improve from 0.91221
# 240/240 [==============================] - 1374s 6s/step - loss: 0.0332 - f1_score: 0.9893 - val_loss: 0.6696 - val_f1_score: 0.9012
# Epoch 28/100
# 240/240 [==============================] - ETA: 0s - loss: 0.0404 - f1_score: 0.9883
# Epoch 28: val_f1_score did not improve from 0.91221
# 240/240 [==============================] - 1425s 6s/step - loss: 0.0404 - f1_score: 0.9883 - val_loss: 0.6056 - val_f1_score: 0.8961
# Epoch 29/100
# 240/240 [==============================] - ETA: 0s - loss: 0.0116 - f1_score: 0.9960
# Epoch 29: val_f1_score did not improve from 0.91221
# 240/240 [==============================] - 1420s 6s/step - loss: 0.0116 - f1_score: 0.9960 - val_loss: 0.6517 - val_f1_score: 0.9086
# Epoch 30/100
# 240/240 [==============================] - ETA: 0s - loss: 0.0166 - f1_score: 0.9943
# Epoch 30: val_f1_score did not improve from 0.91221
# 240/240 [==============================] - 1416s 6s/step - loss: 0.0166 - f1_score: 0.9943 - val_loss: 0.8901 - val_f1_score: 0.8737
# Epoch 31/100
# 240/240 [==============================] - ETA: 0s - loss: 0.0359 - f1_score: 0.9872
# Epoch 31: val_f1_score did not improve from 0.91221
# 240/240 [==============================] - 1427s 6s/step - loss: 0.0359 - f1_score: 0.9872 - val_loss: 0.6528 - val_f1_score: 0.9022
# Epoch 32/100
# 240/240 [==============================] - ETA: 0s - loss: 0.0073 - f1_score: 0.9980
# Epoch 32: val_f1_score did not improve from 0.91221
# 240/240 [==============================] - 1422s 6s/step - loss: 0.0073 - f1_score: 0.9980 - val_loss: 0.7278 - val_f1_score: 0.8966
# Epoch 33/100
# 240/240 [==============================] - ETA: 0s - loss: 0.0015 - f1_score: 0.9997
# Epoch 33: val_f1_score did not improve from 0.91221
# 240/240 [==============================] - 1374s 6s/step - loss: 0.0015 - f1_score: 0.9997 - val_loss: 0.8100 - val_f1_score: 0.9066
# Epoch 34/100
# 240/240 [==============================] - ETA: 0s - loss: 2.1700e-04 - f1_score: 1.0000
# Epoch 34: val_f1_score did not improve from 0.91221
# 240/240 [==============================] - 1276s 5s/step - loss: 2.1700e-04 - f1_score: 1.0000 - val_loss: 0.8585 - val_f1_score: 0.9040
# Epoch 35/100
# 240/240 [==============================] - ETA: 0s - loss: 4.8267e-05 - f1_score: 1.0000
# Epoch 35: val_f1_score did not improve from 0.91221
# 240/240 [==============================] - 1408s 6s/step - loss: 4.8267e-05 - f1_score: 1.0000 - val_loss: 0.8808 - val_f1_score: 0.9064
# Epoch 36/100
# 240/240 [==============================] - ETA: 0s - loss: 2.9449e-05 - f1_score: 1.0000
# Epoch 36: val_f1_score did not improve from 0.91221
# 240/240 [==============================] - 1402s 6s/step - loss: 2.9449e-05 - f1_score: 1.0000 - val_loss: 0.9070 - val_f1_score: 0.9046
# Epoch 36: early stopping
# 60/60 [==============================] - 105s 2s/step - loss: 0.9070 - f1_score: 0.9048

# %%
best_epochLocation = history.history['val_f1_score'].index(max(history.history['val_f1_score']))
best_epochLocation
# Out:
# 25

# %%
best_history = {key: values[:best_epochLocation + 1] for key, values in history.history.items()}
best_history
# Out:
# {'loss': [0.6972348690032959,
#   0.45274290442466736,
#   0.3257076144218445,
#   0.27941134572029114,
#   0.25056684017181396,
#   0.2252122461795807,
#   0.19481481611728668,
#   0.18034933507442474,
#   0.1460055410861969,
#   0.11262106895446777,
#   0.08999554067850113,
#   0.06040320172905922,
#   0.0816098153591156,
#   0.05922674760222435,
#   0.04569590464234352,
#   0.03313228860497475,
#   0.023242687806487083,
#   0.04489004239439964,
#   0.03509550914168358,
#   0.027895314618945122,
#   0.01711767539381981,
#   0.026335489004850388,
#   0.02268919162452221,
#   0.04209627956151962,
#   0.007395180407911539,
#   0.0021944954060018063],
#  'f1_score': [0.6070189476013184,
#   0.7967820763587952,
#   0.8651615381240845,
#   0.8895297646522522,
#   0.9018071293830872,
#   0.9117646813392639,
#   0.9251439571380615,
#   0.93001788854599,
#   0.9436619877815247,
#   0.9583927392959595,
#   0.9643134474754333,
#   0.9767623543739319,
#   0.9693204164505005,
#   0.9772607684135437,
#   0.9835556149482727,
#   0.9882782101631165,
#   0.9927102327346802,
#   0.9838730692863464,
#   0.9890767931938171,
#   0.9902635216712952,
#   0.9945369362831116,
#   0.990602970123291,
#   0.9903570413589478,
#   0.9862122535705566,
#   0.9973849654197693,
#   0.9996092319488525],
#  'val_loss': [0.5471031069755554,
#   0.38132721185684204,
#   0.3788544535636902,
#   0.32582199573516846,
#   0.28235313296318054,
#   0.37724870443344116,
#   0.2791091799736023,
#   0.32658207416534424,
#   0.35931137204170227,
#   0.35677164793014526,
#   0.424804151058197,
#   0.4937942624092102,
#   0.4735664129257202,
#   0.44490846991539,
#   0.6011455655097961,
#   0.4827757477760315,
#   0.8002548217773438,
#   0.6281430125236511,
#   0.5771917104721069,
#   0.5746976137161255,
#   0.7190386056900024,
#   0.7079422473907471,
#   0.7187105417251587,
#   0.564355194568634,
#   0.6456512212753296,
#   0.7225428819656372],
#  'val_f1_score': [0.7645590901374817,
#   0.8294491171836853,
#   0.8529813885688782,
#   0.8548124432563782,
#   0.8910486102104187,
#   0.821885883808136,
#   0.8943731188774109,
#   0.8924145102500916,
#   0.8914926052093506,
#   0.8925114870071411,
#   0.8871139287948608,
#   0.8980858325958252,
#   0.8944976925849915,
#   0.8969636559486389,
#   0.8883274793624878,
#   0.9077231884002686,
#   0.8904593586921692,
#   0.8959507942199707,
#   0.8688352704048157,
#   0.9060169458389282,
#   0.886400043964386,
#   0.8664458990097046,
#   0.8928210139274597,
#   0.8819875717163086,
#   0.8865979909896851,
#   0.9122098684310913]}

# %%
model.save('C:/Users/v4run/OneDrive/Desktop/Datasets/C-NMC_Leukemia/models/fourLayerModel.h5')

# %%
savedModel = tf.keras.models.load_model('C:/Users/v4run/OneDrive/Desktop/Datasets/C-NMC_Leukemia/models/parallelBranch.h5')

# %%
acc = best_history['f1_score']
loss = best_history['loss']
val_acc = best_history['val_f1_score']
val_loss = best_history['val_loss']

# %%
epoch = range(1, len(acc)+1)

# %%
plt.plot(epoch, acc, 'r', label = 'Training acc')
plt.plot(epoch, val_acc, 'b', label = 'Validation acc')
plt.title('Training and Validation accuracy')
plt.legend()
plt.show()

# %%
plt.plot(epoch, loss, 'r', label = 'Training acc')
plt.plot(epoch, val_loss, 'b', label = 'Validation acc')
plt.title('Training and Validation accuracy')
plt.legend()
plt.show()

# %%
# Test Data

# %%
testingDataPath = 'C:/Users/v4run/OneDrive/Desktop/Datasets/C-NMC_Leukemia/training_data/fold_2'

# %%
test_data = tf.keras.utils.image_dataset_from_directory(
    testingDataPath,
    seed=21,
    image_size=(256, 256),
    batch_size=32
)
# Out:
# Found 3553 files belonging to 2 classes.

# %%
#crop Data

# %%
def imgCropPreprocess(images,labels):
    cropped_images = tf.map_fn(lambda img: tf.py_function(crop_img, [img], Tout=tf.float32), images)
    return cropped_images,labels

# %%
testCropped_data = test_data.map(imgCropPreprocess)

# %%
a = testCropped_data.as_numpy_iterator()

# %%
img, label = a.next()

# %%
imshow(img[0])

# %%
testCont_data = testCropped_data.map(imgContrastPreprocess)

# %%
saved_model = tf.keras.models.load_model('C:/Users/v4run/OneDrive/Desktop/Datasets/C-NMC_Leukemia/models/parallelBranch.h5')

# %%
# prediction

# %%
y_predict = saved_model.predict(testCont_data)
# Out:
# 112/112 [==============================] - 223s 2s/step

# %%
y_predict_binary = (y_predict>0.5).astype(int)

# %%
y_pred = np.round(y_predict).flatten()

# %%
y_predict_binary
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]])

# %%
y_pred
# Out:
# array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)

# %%
y_true = np.concatenate([y for x, y in testCont_data], axis=0)

# %%
precision = precision_score(y_true,y_pred)
recall = recall_score(y_true,y_pred)
f1Score = f1_score(y_true, y_pred)

print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print(f'f1_score: {f1Score:.4f}')
# Out:
# Precision: 0.6885
# Recall: 0.1368
# f1_score: 0.2282

# %%
confusionMatrix = confusion_matrix(y_true, y_predict_binary)
print(confusionMatrix)
# Out:
# [[ 944  152]
#  [2121  336]]

# %%
layer_names = [layer.name for layer in saved_model.layers if 'conv' in layer.name]
visualize_model = Model(inputs=saved_model.inputs, outputs=[saved_model.get_layer(name).output for name in layer_names])

# %%
a = testCont_data.as_numpy_iterator()

# %%
img1, label1 = a.next()

# %%
img10,label10 = img1[0],label1[0]

# %%
imshow(img10)

# %%
label10
# Out:
# 1

# %%
img10 = np.expand_dims(img10,axis=0)

# %%
saved_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 32  896         ['input_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 32  0           ['conv2d[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 64  18496       ['max_pooling2d[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 64)  0           ['conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 128)  0          ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 256)  295168      ['max_pooling2d_2[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 256)  819456      ['max_pooling2d_2[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 256)  1605888     ['max_pooling2d_2[0][0]']
#
#  concatenate (Concatenate)      (None, 32, 32, 768)  0           ['conv2d_3[0][0]',
#                                                                   'conv2d_4[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 256)  1769728     ['concatenate[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 256)  0          ['conv2d_6[0][0]']
#
#  flatten (Flatten)              (None, 65536)        0           ['max_pooling2d_3[0][0]']
#
#  dense (Dense)                  (None, 256)          16777472    ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 1)            257         ['dense[0][0]']
#
# ==================================================================================================
# Total params: 21,361,217
# Trainable params: 21,361,217
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
(saved_model.predict(img10)>0.5).astype(int)
# Out:
# 1/1 [==============================] - 0s 181ms/step
# array([[0]])

# %%
activations = visualize_model(img10)

# %%
def display_feature_maps(activations, layer_names):
    for i, activation in enumerate(activations):
        layer_name = layer_names[i]
        num_filters = activation.shape[-1]

        # Calculate the number of rows and columns for the grid
        no_cols = 8
        grid_rows = num_filters // no_cols

        fig, axes = plt.subplots(grid_rows, no_cols, figsize=(15, 15))
        fig.suptitle(f"Feature maps for layer {layer_name}")

        for j in range(num_filters):
            ax = axes[j // no_cols, j % no_cols]
            ax.imshow(activation[0, :, :, j], cmap='viridis')
            ax.axis('off')

        plt.show()

# Call the function with the activations and layer names
display_feature_maps(activations, layer_names)
